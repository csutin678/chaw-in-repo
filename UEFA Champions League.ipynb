# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv('UCL Final.csv')
df.head()
# Out:
#              club  nation                   coach formation      mvp  \
# 0  Real Madrid CF   Spain         José Villalonga   unknown  unknown
# 1  Stade de Reims  France          Albert Batteux   unknown  unknown
# 2  Real Madrid CF   Spain         José Villalonga   unknown  unknown
# 3  ACF Fiorentina   Italy       Fulvio Bernardini   unknown  unknown
# 4  Real Madrid CF   Spain  Luis Antonio Carniglia   unknown  unknown
#
#     position       season
# 0     winner  '1955/1956'
# 1  runner up  '1955/1956'
# 2     winner  '1956/1957'
# 3  runner up  '1956/1957'
# 4     winner  '1957/1958'

# %%
df.isnull().sum()
# Out:
# club         0
# nation       0
# coach        0
# formation    0
# mvp          0
# position     0
# season       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   club       128 non-null    object
#  1   nation     128 non-null    object
#  2   coach      128 non-null    object
#  3   formation  128 non-null    object
#  4   mvp        128 non-null    object
#  5   position   128 non-null    object
#  6   season     128 non-null    object
# dtypes: object(7)
# memory usage: 7.1+ KB

# %%
sns.set(rc={'figure.figsize':(18,9), 'lines.linewidth': 5, 'lines.markersize': 5, "axes.labelsize":15}, style="whitegrid")

best_team = df.club[df['position'] == 'winner'].value_counts()

# %%
sns.barplot(x=best_team, y=best_team.index, data=df)
# Out:
# <AxesSubplot:xlabel='club'>

# %%
most_team = df['club'].value_counts()

# %%
sns.barplot(x=most_team, y=most_team.index, data=df)
# Out:
# <AxesSubplot:xlabel='club'>
